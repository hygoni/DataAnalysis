# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import pandas as pd
import numpy as np
import mpl_finance
from IPython.display import clear_output

# %%
date = [20180807, 20180808, 20180809, 20180810, 20180813, 20180814, 20180816, 20180817, 20180820, 20180821, 20180822, 20180823, 20180824, 20180827, 20180828, 20180829, 20180830, 20180831, 20180903, 20180904] * 10
open = [142500, 155000, 153500, 142000, 145000, 141500, 141500, 140500, 138500, 137500, 138500, 139500, 135500, 135000, 135500, 135000, 135500, 132500, 132500, 132400] * 10
high = [145500, 145000, 144000, 146500, 146000, 146000, 142000, 141000, 140000, 140000, 140000, 140000, 137000, 136500, 136000, 136000, 136000, 133500, 133500, 133500] * 10
low = [142000, 141500, 142000, 142000, 141000, 141500, 138500, 137000, 137500, 137500, 138500, 135000, 132000, 134000, 133000, 134000, 131500, 131000, 132000, 131500] * 10
close = [145000, 143500, 142000, 146000, 142000, 142500, 141000, 138500, 137500, 140000, 139000, 136000, 134500, 135000, 135000, 135500, 132500, 132000, 132000,133500] * 10
volume = [63103, 39191, 63800, 57283, 51095, 42579, 66262, 100717, 53507, 40399, 34023, 95824, 118459, 67489, 66626, 64548, 141496, 100410, 37159, 35215] * 10

from collections import OrderedDict
df = pd.DataFrame(OrderedDict(
[    ('date', date),
    ('open', open),
    ('high', high),
    ('low', low),
    ('close', close),
    ('volume', volume)]
))
df.head()
# Out:
#        date    open    high     low   close  volume
# 0  20180807  142500  145500  142000  145000   63103
# 1  20180808  155000  145000  141500  143500   39191
# 2  20180809  153500  144000  142000  142000   63800
# 3  20180810  142000  146500  142000  146000   57283
# 4  20180813  145000  146000  141000  142000   51095

# %%
from time import sleep
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

size = 10
fig = plt.figure(figsize=(6, 4))
ax = fig.add_subplot(111)
plt.ion()

for i in range(0, len(df)+1 - size):
    df_tmp = df[i:i+size]
    mpl_finance.candlestick2_ohlc(ax, df_tmp['open'], df_tmp['high'], df_tmp['low'], df_tmp['close'],
                                 width = 0.5, colorup='r', colordown='b')
    plt.grid()
    fig.show()
    fig.canvas.draw()
    ax.clear()
    sleep(0.5)
# Out:
# <img src="data:image/png;base64,..." width="600">
